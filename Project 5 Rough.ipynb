# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline 
pd.set_option('display.max_columns',500)

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 58D2-4134
#
#  Directory of C:\Users\DELL\FLATIRON_LEARN\05_SECTION\dsc-data-cleaning-project-onl01-dtsc-pt-070620
#
# 01-08-2020  01:56    <DIR>          .
# 01-08-2020  01:56    <DIR>          ..
# 26-07-2020  19:57                29 .gitignore
# 26-07-2020  20:46    <DIR>          .ipynb_checkpoints
# 26-07-2020  19:57                95 .learn
# 26-07-2020  19:57                 0 .misc
# 26-07-2020  19:57             1,846 CONTRIBUTING.md
# 26-07-2020  19:57            49,195 heroes_information.csv
# 26-07-2020  21:05            17,017 index.ipynb
# 26-07-2020  19:57             1,354 LICENSE.md
# 01-08-2020  01:56            21,572 Project 5 Rough.ipynb
# 26-07-2020  19:57             8,902 README.md
# 26-07-2020  19:57           672,305 super_hero_powers.csv
#               10 File(s)        772,315 bytes
#                3 Dir(s)  854,364,819,456 bytes free

# %%
heroes_df = pd.read_csv('heroes_information.csv')
powers_df = pd.read_csv('super_hero_powers.csv')

# %%
heroes_df.head()
# Out:
#    Unnamed: 0         name Gender Eye color               Race Hair color  \
# 0           0       A-Bomb   Male    yellow              Human    No Hair
# 1           1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair
# 2           2     Abin Sur   Male      blue            Ungaran    No Hair
# 3           3  Abomination   Male     green  Human / Radiation    No Hair
# 4           4      Abraxas   Male      blue      Cosmic Entity      Black
#
#    Height          Publisher Skin color Alignment  Weight
# 0   203.0      Marvel Comics          -      good   441.0
# 1   191.0  Dark Horse Comics       blue      good    65.0
# 2   185.0          DC Comics        red      good    90.0
# 3   203.0      Marvel Comics          -       bad   441.0
# 4   -99.0      Marvel Comics          -       bad   -99.0

# %%
powers_df.head()
# Out:
#     hero_names  Agility  Accelerated Healing  Lantern Power Ring  \
# 0      3-D Man     True                False               False
# 1       A-Bomb    False                 True               False
# 2   Abe Sapien     True                 True               False
# 3     Abin Sur    False                False                True
# 4  Abomination    False                 True               False
#
#    Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 0                  False            False       False    False
# 1                  False            False        True    False
# 2                  False             True        True    False
# 3                  False            False       False    False
# 4                  False            False       False    False
#
#    Energy Absorption  Flight  Danger Sense  Underwater breathing  \
# 0              False   False         False                 False
# ...

# %%
heroes_df.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0             name  Gender Eye color               Race  \
# 0             0           A-Bomb    Male    yellow              Human
# 1             1       Abe Sapien    Male      blue      Icthyo Sapien
# 2             2         Abin Sur    Male      blue            Ungaran
# 3             3      Abomination    Male     green  Human / Radiation
# 4             4          Abraxas    Male      blue      Cosmic Entity
# ..          ...              ...     ...       ...                ...
# 729         729  Yellowjacket II  Female      blue              Human
# 730         730             Ymir    Male     white        Frost Giant
# 731         731             Yoda    Male     brown     Yoda's species
# 732         732          Zatanna  Female      blue              Human
# 733         733             Zoom    Male       red                  -
#
#            Hair color  Height          Publisher Skin color Alignment  Weight
# ...

# %%
powers_df.info
# Out:
# <bound method DataFrame.info of           hero_names  Agility  Accelerated Healing  Lantern Power Ring  \
# 0            3-D Man     True                False               False
# 1             A-Bomb    False                 True               False
# 2         Abe Sapien     True                 True               False
# 3           Abin Sur    False                False                True
# 4        Abomination    False                 True               False
# ..               ...      ...                  ...                 ...
# 662  Yellowjacket II    False                False               False
# 663             Ymir    False                False               False
# 664             Yoda     True                False               False
# 665          Zatanna    False                False               False
# 666             Zoom    False                False               False
#
#      Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# ...

# %%
powers_df.tail()
# Out:
#           hero_names  Agility  Accelerated Healing  Lantern Power Ring  \
# 662  Yellowjacket II    False                False               False
# 663             Ymir    False                False               False
# 664             Yoda     True                False               False
# 665          Zatanna    False                False               False
# 666             Zoom    False                False               False
#
#      Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 662                  False            False       False    False
# 663                  False             True        True    False
# 664                  False            False       False     True
# 665                  False            False       False    False
# 666                  False            False       False    False
#
#      Energy Absorption  Flight  Danger Sense  Underwater breathing  \
# 662              False    True         False                 False
# ...

# %%
heroes_df.tail()
# Out:
#      Unnamed: 0             name  Gender Eye color            Race  \
# 729         729  Yellowjacket II  Female      blue           Human
# 730         730             Ymir    Male     white     Frost Giant
# 731         731             Yoda    Male     brown  Yoda's species
# 732         732          Zatanna  Female      blue           Human
# 733         733             Zoom    Male       red               -
#
#            Hair color  Height      Publisher Skin color Alignment  Weight
# 729  Strawberry Blond   165.0  Marvel Comics          -      good    52.0
# 730           No Hair   304.8  Marvel Comics      white      good   -99.0
# 731             White    66.0   George Lucas      green      good    17.0
# 732             Black   170.0      DC Comics          -      good    57.0
# 733             Brown   185.0      DC Comics          -       bad    81.0

# %%
heroes_df.drop('Unnamed: 0',axis = 1, inplace= True)

# %%
heroes_df.head()
# Out:
#           name Gender Eye color               Race Hair color  Height  \
# 0       A-Bomb   Male    yellow              Human    No Hair   203.0
# 1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur   Male      blue            Ungaran    No Hair   185.0
# 3  Abomination   Male     green  Human / Radiation    No Hair   203.0
# 4      Abraxas   Male      blue      Cosmic Entity      Black   -99.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0
# 3      Marvel Comics          -       bad   441.0
# 4      Marvel Comics          -       bad   -99.0

# %%
heroes_df.shape, powers_df.shape
# Out:
# ((734, 10), (667, 168))

# %%
heroes_df.describe()
# Out:
#            Height      Weight
# count  734.000000  732.000000
# mean   102.254087   43.855191
# std    139.624543  130.823733
# min    -99.000000  -99.000000
# 25%    -99.000000  -99.000000
# 50%    175.000000   62.000000
# 75%    185.000000   90.000000
# max    975.000000  900.000000

# %%
powers_df.describe()
# Out:
#         hero_names Agility Accelerated Healing Lantern Power Ring  \
# count          667     667                 667                667
# unique         667       2                   2                  2
# top     Lara Croft   False               False              False
# freq             1     425                 489                656
#
#        Dimensional Awareness Cold Resistance Durability Stealth  \
# count                    667             667        667     667
# unique                     2               2          2       2
# top                    False           False      False   False
# freq                     642             620        410     541
#
#        Energy Absorption Flight Danger Sense Underwater breathing  \
# count                667    667          667                  667
# unique                 2      2            2                    2
# top                False  False        False                False
# ...

# %%
heroes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 734 entries, 0 to 733
# Data columns (total 10 columns):
# name          734 non-null object
# Gender        734 non-null object
# Eye color     734 non-null object
# Race          734 non-null object
# Hair color    734 non-null object
# Height        734 non-null float64
# Publisher     719 non-null object
# Skin color    734 non-null object
# Alignment     734 non-null object
# Weight        732 non-null float64
# dtypes: float64(2), object(8)
# memory usage: 57.5+ KB

# %%
powers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Columns: 168 entries, hero_names to Omniscient
# dtypes: bool(167), object(1)
# memory usage: 114.1+ KB

# %%
heroes_df.isnull().sum()
# Out:
# name           0
# Gender         0
# Eye color      0
# Race           0
# Hair color     0
# Height         0
# Publisher     15
# Skin color     0
# Alignment      0
# Weight         2
# dtype: int64

# %%
powers_df.isnull().sum()
# Out:
# hero_names               0
# Agility                  0
# Accelerated Healing      0
# Lantern Power Ring       0
# Dimensional Awareness    0
#                         ..
# Phoenix Force            0
# Molecular Dissipation    0
# Vision - Cryo            0
# Omnipresent              0
# Omniscient               0
# Length: 168, dtype: int64

# %%
list(powers_df.columns)
# Out:
# ['hero_names',
#  'Agility',
#  'Accelerated Healing',
#  'Lantern Power Ring',
#  'Dimensional Awareness',
#  'Cold Resistance',
#  'Durability',
#  'Stealth',
#  'Energy Absorption',
#  'Flight',
#  'Danger Sense',
#  'Underwater breathing',
#  'Marksmanship',
#  'Weapons Master',
#  'Power Augmentation',
#  'Animal Attributes',
#  'Longevity',
#  'Intelligence',
#  'Super Strength',
#  'Cryokinesis',
#  'Telepathy',
#  'Energy Armor',
#  'Energy Blasts',
#  'Duplication',
#  'Size Changing',
#  'Density Control',
#  'Stamina',
#  'Astral Travel',
#  'Audio Control',
#  'Dexterity',
#  'Omnitrix',
#  'Super Speed',
#  'Possession',
#  'Animal Oriented Powers',
#  'Weapon-based Powers',
#  'Electrokinesis',
#  'Darkforce Manipulation',
#  'Death Touch',
#  'Teleportation',
#  'Enhanced Senses',
#  'Telekinesis',
#  'Energy Beams',
#  'Magic',
#  'Hyperkinesis',
#  'Jump',
#  'Clairvoyance',
#  'Dimensional Travel',
#  'Power Sense',
#  'Shapeshifting',
#  'Peak Human Condition',
# ...

# %%
list(heroes_df.columns)
# Out:
# ['name',
#  'Gender',
#  'Eye color',
#  'Race',
#  'Hair color',
#  'Height',
#  'Publisher',
#  'Skin color',
#  'Alignment',
#  'Weight']

# %%
powers_df.head(3)
# Out:
#    hero_names  Agility  Accelerated Healing  Lantern Power Ring  \
# 0     3-D Man     True                False               False
# 1      A-Bomb    False                 True               False
# 2  Abe Sapien     True                 True               False
#
#    Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 0                  False            False       False    False
# 1                  False            False        True    False
# 2                  False             True        True    False
#
#    Energy Absorption  Flight  Danger Sense  Underwater breathing  \
# 0              False   False         False                 False
# 1              False   False         False                 False
# 2              False   False         False                  True
#
#    Marksmanship  Weapons Master  Power Augmentation  Animal Attributes  \
# 0         False           False               False              False
# ...

# %%
heroes_df.head(2)
# Out:
#          name Gender Eye color           Race Hair color  Height  \
# 0      A-Bomb   Male    yellow          Human    No Hair   203.0
# 1  Abe Sapien   Male      blue  Icthyo Sapien    No Hair   191.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0

# %%
heroes_df['Publisher'].value_counts()
# Out:
# Marvel Comics        388
# DC Comics            215
# NBC - Heroes          19
# Dark Horse Comics     18
# George Lucas          14
# Image Comics          14
# Star Trek              6
# HarperCollins          6
# SyFy                   5
# Team Epic TV           5
# IDW Publishing         4
# Shueisha               4
# ABC Studios            4
# Icon Comics            4
# Wildstorm              3
# Sony Pictures          2
# Hanna-Barbera          1
# Universal Studios      1
# South Park             1
# Rebellion              1
# Titan Books            1
# J. R. R. Tolkien       1
# Microsoft              1
# J. K. Rowling          1
# Name: Publisher, dtype: int64

# %%
heroes_df.isnull().sum()/len(heroes_df)
# Out:
# name          0.000000
# Gender        0.000000
# Eye color     0.000000
# Race          0.000000
# Hair color    0.000000
# Height        0.000000
# Publisher     0.020436
# Skin color    0.000000
# Alignment     0.000000
# Weight        0.002725
# dtype: float64

# %%
heroes_df.dropna(subset=['Publisher'], inplace= True)

# %%
heroes_df.shape
# Out:
# (719, 10)

# %%
heroes_df.isnull().sum()
# Out:
# name          0
# Gender        0
# Eye color     0
# Race          0
# Hair color    0
# Height        0
# Publisher     0
# Skin color    0
# Alignment     0
# Weight        0
# dtype: int64

# %%
powers_df.isnull().sum()
# Out:
# hero_names               0
# Agility                  0
# Accelerated Healing      0
# Lantern Power Ring       0
# Dimensional Awareness    0
#                         ..
# Phoenix Force            0
# Molecular Dissipation    0
# Vision - Cryo            0
# Omnipresent              0
# Omniscient               0
# Length: 168, dtype: int64

# %%
powers_df.isnull().sum().sum()
# Out:
# 0

# %%
heroes_df.head()
# Out:
#           name Gender Eye color               Race Hair color  Height  \
# 0       A-Bomb   Male    yellow              Human    No Hair   203.0
# 1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur   Male      blue            Ungaran    No Hair   185.0
# 3  Abomination   Male     green  Human / Radiation    No Hair   203.0
# 4      Abraxas   Male      blue      Cosmic Entity      Black   -99.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0
# 3      Marvel Comics          -       bad   441.0
# 4      Marvel Comics          -       bad   -99.0

# %%
powers_df.head()
# Out:
#     hero_names  Agility  Accelerated Healing  Lantern Power Ring  \
# 0      3-D Man     True                False               False
# 1       A-Bomb    False                 True               False
# 2   Abe Sapien     True                 True               False
# 3     Abin Sur    False                False                True
# 4  Abomination    False                 True               False
#
#    Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 0                  False            False       False    False
# 1                  False            False        True    False
# 2                  False             True        True    False
# 3                  False            False       False    False
# 4                  False            False       False    False
#
#    Energy Absorption  Flight  Danger Sense  Underwater breathing  \
# 0              False   False         False                 False
# ...

# %%
heroes_df.merge(powers_df, left_on= 'name', right_on = 'hero_names')
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 4            Abraxas    Male      blue      Cosmic Entity             Black
# ..               ...     ...       ...                ...               ...
# 642  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 643             Ymir    Male     white        Frost Giant           No Hair
# 644             Yoda    Male     brown     Yoda's species             White
# 645          Zatanna  Female      blue              Human             Black
# 646             Zoom    Male       red                  -             Brown
#
# ...

# %%
df = heroes_df.merge(powers_df, left_on= 'name', right_on = 'hero_names')

# %%
df.head(2)
# Out:
#          name Gender Eye color           Race Hair color  Height  \
# 0      A-Bomb   Male    yellow          Human    No Hair   203.0
# 1  Abe Sapien   Male      blue  Icthyo Sapien    No Hair   191.0
#
#            Publisher Skin color Alignment  Weight  hero_names  Agility  \
# 0      Marvel Comics          -      good   441.0      A-Bomb    False
# 1  Dark Horse Comics       blue      good    65.0  Abe Sapien     True
#
#    Accelerated Healing  Lantern Power Ring  Dimensional Awareness  \
# 0                 True               False                  False
# 1                 True               False                  False
#
#    Cold Resistance  Durability  Stealth  Energy Absorption  Flight  \
# 0            False        True    False              False   False
# 1             True        True    False              False   False
#
#    Danger Sense  Underwater breathing  Marksmanship  Weapons Master  \
# 0         False                 False         False           False
# ...

# %%
df_male = df[df['Gender'] == 'Male']
df_female = df[df['Gender'] == 'Female']

# %%
plt.style.use('ggplot')
plt.xkcd()

# %%
fig = plt.figure(figsize = (12, 8))
fig.suptitle('Superheros')

axl = plt.subplot(1, 2, 1)
plt.scatter(df_male['Height'], df_male['Weight'])
axl.set_title('Male Superheros')

ax2 = plt.subplot(1, 2, 2) # just changed name of axis from ax1 to ax2 and plt number from 1 to 2
plt.scatter(df_female['Height'], df_female['Weight'])
ax2.set_title('Female Superheros')
# Out:
# Text(0.5, 1.0, 'Female Superheros')

# %%
def show_distplot(dataframe, gender, column_name):
    sns.distplot(dataframe[column_name])
    plt.title(f'{gender} {column_name}')

# %%
show_distplot(df_male, 'Male', 'Height')

# %%
show_distplot(df_male, 'Male', 'Weight')

# %%
show_distplot(df_female, 'Female', 'Weight')

# %%
show_distplot(df_female, 'Female', 'Height')

# %%
list(df.columns)
# Out:
# ['name',
#  'Gender',
#  'Eye color',
#  'Race',
#  'Hair color',
#  'Height',
#  'Publisher',
#  'Skin color',
#  'Alignment',
#  'Weight',
#  'hero_names',
#  'Agility',
#  'Accelerated Healing',
#  'Lantern Power Ring',
#  'Dimensional Awareness',
#  'Cold Resistance',
#  'Durability',
#  'Stealth',
#  'Energy Absorption',
#  'Flight',
#  'Danger Sense',
#  'Underwater breathing',
#  'Marksmanship',
#  'Weapons Master',
#  'Power Augmentation',
#  'Animal Attributes',
#  'Longevity',
#  'Intelligence',
#  'Super Strength',
#  'Cryokinesis',
#  'Telepathy',
#  'Energy Armor',
#  'Energy Blasts',
#  'Duplication',
#  'Size Changing',
#  'Density Control',
#  'Stamina',
#  'Astral Travel',
#  'Audio Control',
#  'Dexterity',
#  'Omnitrix',
#  'Super Speed',
#  'Possession',
#  'Animal Oriented Powers',
#  'Weapon-based Powers',
#  'Electrokinesis',
#  'Darkforce Manipulation',
#  'Death Touch',
#  'Teleportation',
#  'Enhanced Senses',
#  'Telekinesis',
#  'Energy Beams',
# ...

# %% [markdown]
# 5 most common powers over all

# %%
df['Agility'].sum()
# Out:
# 236

# %%
for x in list(df.columns)[11:]:
    print(x)
# Out:
# Agility
# Accelerated Healing
# Lantern Power Ring
# Dimensional Awareness
# Cold Resistance
# Durability
# Stealth
# Energy Absorption
# Flight
# Danger Sense
# Underwater breathing
# Marksmanship
# Weapons Master
# Power Augmentation
# Animal Attributes
# Longevity
# Intelligence
# Super Strength
# Cryokinesis
# Telepathy
# Energy Armor
# Energy Blasts
# Duplication
# Size Changing
# Density Control
# Stamina
# Astral Travel
# Audio Control
# Dexterity
# Omnitrix
# Super Speed
# Possession
# Animal Oriented Powers
# Weapon-based Powers
# Electrokinesis
# Darkforce Manipulation
# Death Touch
# Teleportation
# Enhanced Senses
# Telekinesis
# Energy Beams
# Magic
# Hyperkinesis
# Jump
# Clairvoyance
# Dimensional Travel
# Power Sense
# Shapeshifting
# Peak Human Condition
# Immortality
# Camouflage
# Element Control
# Phasing
# Astral Projection
# Electrical Transport
# Fire Control
# Projection
# Summoning
# Enhanced Memory
# Reflexes
# Invulnerability
# Energy Constructs
# ...

# %%
powers_dict = {}
for x in list(df.columns)[11:]:
    powers_dict[x] = df[x].sum()

# %%
powers_dict
# Out:
# {'Agility': 236,
#  'Accelerated Healing': 181,
#  'Lantern Power Ring': 11,
#  'Dimensional Awareness': 25,
#  'Cold Resistance': 49,
#  'Durability': 256,
#  'Stealth': 126,
#  'Energy Absorption': 76,
#  'Flight': 211,
#  'Danger Sense': 33,
#  'Underwater breathing': 23,
#  'Marksmanship': 119,
#  'Weapons Master': 103,
#  'Power Augmentation': 8,
#  'Animal Attributes': 26,
#  'Longevity': 114,
#  'Intelligence': 156,
#  'Super Strength': 357,
#  'Cryokinesis': 20,
#  'Telepathy': 92,
#  'Energy Armor': 8,
#  'Energy Blasts': 146,
#  'Duplication': 17,
#  'Size Changing': 55,
#  'Density Control': 15,
#  'Stamina': 286,
#  'Astral Travel': 4,
#  'Audio Control': 8,
#  'Dexterity': 6,
#  'Omnitrix': 1,
#  'Super Speed': 248,
#  'Possession': 7,
#  'Animal Oriented Powers': 41,
#  'Weapon-based Powers': 60,
#  'Electrokinesis': 20,
#  'Darkforce Manipulation': 9,
#  'Death Touch': 7,
#  'Teleportation': 70,
#  'Enhanced Senses': 91,
#  'Telekinesis': 61,
#  'Energy Beams': 41,
# ...

# %%
sorted(powers_dict.items(), key=lambda y: y[1],reverse=True)
# Out:
# [('Super Strength', 357),
#  ('Stamina', 286),
#  ('Durability', 256),
#  ('Super Speed', 248),
#  ('Agility', 236),
#  ('Flight', 211),
#  ('Accelerated Healing', 181),
#  ('Reflexes', 169),
#  ('Intelligence', 156),
#  ('Energy Blasts', 146),
#  ('Stealth', 126),
#  ('Marksmanship', 119),
#  ('Invulnerability', 115),
#  ('Longevity', 114),
#  ('Weapons Master', 103),
#  ('Telepathy', 92),
#  ('Enhanced Senses', 91),
#  ('Force Fields', 86),
#  ('Energy Absorption', 76),
#  ('Teleportation', 70),
#  ('Immortality', 68),
#  ('Enhanced Hearing', 68),
#  ('Shapeshifting', 65),
#  ('Jump', 64),
#  ('Telekinesis', 61),
#  ('Weapon-based Powers', 60),
#  ('Natural Weapons', 58),
#  ('Size Changing', 55),
#  ('Energy Manipulation', 53),
#  ('Psionic Powers', 51),
#  ('Toxin and Disease Resistance', 51),
#  ('Cold Resistance', 49),
#  ('Heat Resistance', 45),
#  ('Magic', 44),
#  ('Vision - Telescopic', 44),
#  ('Molecular Manipulation', 43),
#  ('Animal Oriented Powers', 41),
# ...

# %%
len(sorted(powers_dict.items(), key=lambda y: y[1]))
# Out:
# 167

# %%
sorted(powers_dict.items(), key=lambda z: z[1])[162:168]
# Out:
# [('Agility', 236),
#  ('Super Speed', 248),
#  ('Durability', 256),
#  ('Stamina', 286),
#  ('Super Strength', 357)]

# %%
sorted(powers_dict.items(), key=lambda z: z[1])[-5:] # this is to calculate last 5 in the list
# Out:
# [('Agility', 236),
#  ('Super Speed', 248),
#  ('Durability', 256),
#  ('Stamina', 286),
#  ('Super Strength', 357)]

# %%
top_5_overall_powers = sorted(powers_dict.items(), key=lambda z: z[1])[-5:]

# %%
power = [x[0] for x in top_5_overall_powers]
count = [x[1] for x in top_5_overall_powers]

# %%
fig = plt.figure(figsize=(12, 8))
plt.bar(x = power, height= count)
plt.title("Top 5 Common Powers")
# Out:
# Text(0.5, 1.0, 'Top 5 Common Powers')

# %%
df_marvel = df[df['Publisher'] == 'Marvel Comics']
df_marvel['Publisher'].value_counts()
# Out:
# Marvel Comics    341
# Name: Publisher, dtype: int64

# %%
powers_dict_marvel = {}
for x in list(df_marvel.columns)[11:]:
    powers_dict_marvel[x] = df_marvel[x].sum()

# %%
df_dc_comics = df[df['Publisher'] == 'DC Comics']
df_dc_comics['Publisher'].value_counts()
# Out:
# DC Comics    196
# Name: Publisher, dtype: int64

# %%
powers_dict_dc_comics = {}
for x in list(df_dc_comics.columns)[11:]:
    powers_dict_dc_comics[x] = df_dc_comics[x].sum()

# %%
top_5_overall_powers_dc = sorted(powers_dict_dc_comics.items(), key=lambda a: a[1])[-5:]

# %%
top_5_overall_powers_marvel = sorted(powers_dict_marvel.items(), key=lambda b: b[1])[-5:]

# %%
power_marvel = [x[0] for x in top_5_overall_powers_marvel]
count_marvel = [x[1] for x in top_5_overall_powers_marvel]

power_dc = [x[0] for x in top_5_overall_powers_dc]
count_dc = [x[1] for x in top_5_overall_powers_dc]

# %%
fig = plt.figure(figsize=(25, 15))
ax1 = plt.subplot(1, 2, 1) #1 row, two column, one plot
ax1.barh(y = power_marvel, width = count_marvel)
axl.set_title( 'Marvel Super Powers')

ax2 = plt.subplot(1, 2, 2) #1 row, two column, two plot
ax2.barh(y = power_dc, width =count_dc)
ax2.set_title( 'DC Super Powers')
fig.show()
# Out:
# C:\Users\DELL\anaconda3\envs\learn-env\lib\site-packages\ipykernel_launcher.py:9: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   if __name__ == '__main__':

# %%
fig = plt.figure(figsize = (12, 8))
fig.subplots_adjust(hspace=.26)#horizontal space & vspace is for vertical space
ax1 = plt.subplot(2, 1, 2) #1 row, two column, two plot
ax1.barh(y = power_dc, width =count_dc)
ax1.set_title( 'DC 5 Super Powers')
ax2 = plt.subplot(2, 1, 1) #2 row, one column, one plot
ax2.barh(y = power_marvel, width = count_marvel)
ax2.set_title( 'Marvel 5 Super Powers')
# Out:
# Text(0.5, 1.0, 'Marvel 5 Super Powers')

# %% [markdown]
# powers having highest chance of co-occurring in a hero and does this differ by gender

# %%
for x in list(df.columns)[11:]:
    print(x)
# Out:
# Agility
# Accelerated Healing
# Lantern Power Ring
# Dimensional Awareness
# Cold Resistance
# Durability
# Stealth
# Energy Absorption
# Flight
# Danger Sense
# Underwater breathing
# Marksmanship
# Weapons Master
# Power Augmentation
# Animal Attributes
# Longevity
# Intelligence
# Super Strength
# Cryokinesis
# Telepathy
# Energy Armor
# Energy Blasts
# Duplication
# Size Changing
# Density Control
# Stamina
# Astral Travel
# Audio Control
# Dexterity
# Omnitrix
# Super Speed
# Possession
# Animal Oriented Powers
# Weapon-based Powers
# Electrokinesis
# Darkforce Manipulation
# Death Touch
# Teleportation
# Enhanced Senses
# Telekinesis
# Energy Beams
# Magic
# Hyperkinesis
# Jump
# Clairvoyance
# Dimensional Travel
# Power Sense
# Shapeshifting
# Peak Human Condition
# Immortality
# Camouflage
# Element Control
# Phasing
# Astral Projection
# Electrical Transport
# Fire Control
# Projection
# Summoning
# Enhanced Memory
# Reflexes
# Invulnerability
# Energy Constructs
# ...

# %%
df_agility = df[df['Agility'] == True]

# %%
df_agility
# Out:
#              name  Gender Eye color             Race Hair color  Height  \
# 1      Abe Sapien    Male      blue    Icthyo Sapien    No Hair   191.0
# 11           Ajax    Male     brown           Cyborg      Black   193.0
# 13    Alex Mercer    Male         -            Human          -   -99.0
# 15          Alien    Male         -  Xenomorph XX121    No Hair   244.0
# 17          Amazo    Male       red          Android          -   257.0
# ..            ...     ...       ...              ...        ...     ...
# 631  White Canary  Female     brown            Human      Black   -99.0
# 635     Wolverine    Male      blue           Mutant      Black   160.0
# 636   Wonder Girl  Female      blue         Demi-God      Blond   165.0
# 639          X-23  Female     green   Mutant / Clone      Black   155.0
# 644          Yoda    Male     brown   Yoda's species      White    66.0
#
#              Publisher Skin color Alignment  Weight    hero_names  Agility  \
# ...

# %%
df_agility.head(2)
# Out:
#           name Gender Eye color           Race Hair color  Height  \
# 1   Abe Sapien   Male      blue  Icthyo Sapien    No Hair   191.0
# 11        Ajax   Male     brown         Cyborg      Black   193.0
#
#             Publisher Skin color Alignment  Weight  hero_names  Agility  \
# 1   Dark Horse Comics       blue      good    65.0  Abe Sapien     True
# 11      Marvel Comics          -       bad    90.0        Ajax     True
#
#     Accelerated Healing  Lantern Power Ring  Dimensional Awareness  \
# 1                  True               False                  False
# 11                False               False                  False
#
#     Cold Resistance  Durability  Stealth  Energy Absorption  Flight  \
# 1              True        True    False              False   False
# 11            False       False    False              False   False
#
#     Danger Sense  Underwater breathing  Marksmanship  Weapons Master  \
# ...

# %%
df_agility['Accelerated Healing'].sum()/ len(df_agility)
# Out:
# 0.4491525423728814

# %%
highest_percentage = 0
for x in list(df.columns)[11:]:
    if x != 'Agility':
        percent = df_agility[x].sum()/len(df_agility)
        if percent > highest_percentage:
            highest_percentage = percent
            print(x, percent)
# Out:
# Accelerated Healing 0.4491525423728814
# Durability 0.4830508474576271
# Super Strength 0.7033898305084746
# Stamina 0.7330508474576272

# %%
df_agility['Stamina'].sum()/ len(df_agility)
# Out:
# 0.7330508474576272

# %%
highest_co_occurance = 0
for power in list (df.columns)[11:]:
    df_filter = df[df[power] == True]
    for x in list(df.columns)[11:]:
        if x != power :
            cooccurance = df_filter[x].sum()
            if cooccurance > highest_co_occurance:
                highest_co_occurance = cooccurance
                print(power, x, cooccurance)
# Out:
# Agility Accelerated Healing 106
# Agility Durability 114
# Agility Super Strength 166
# Agility Stamina 173
# Durability Super Strength 229
